# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv(r'..\data\output\restaurant_data_with_lat_long.csv')
df.head(5)
# Out:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL  PAGE NO    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...        1  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...        1    Quick Bites
# ...

# %%
#Remove unwanted column like page no
# Here's how to remove a column temporarily:
df.drop('PAGE NO', axis=1, inplace=True)  # axis=1 means column, inplace=True will modify the DataFrame in place
df.head(5)
# Out:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...    Quick Bites
# 2  https://www.zomato.com/agra/bikanervala-khanda...    Quick Bites
# ...

# %%
df1 = pd.read_csv(r'..\data\output\restaurant_data_with_lat_long2.csv')
df1.head(5)
# Out:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL  PAGE NO    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...        1  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...        1    Quick Bites
# ...

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df1['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 10049

# %%
df2 = pd.read_csv(r'..\data\output\restaurant_data_with_lat_long_parallel.csv')
df2.head(5)
# Out:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL  PAGE NO    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...        1  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...        1    Quick Bites
# ...

# %%
# Add an ID column by resetting the index
df1['ID'] = df1.reset_index().index
df2['ID'] = df2.reset_index().index

# %%
df2.head(5)
# Out:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL  PAGE NO    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...        1  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...        1    Quick Bites
# ...

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df2['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 9471

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df1['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 10049

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df2['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 9471

# %%
df1.update(df2)

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df1['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 18658

# %%
df1.head(5)
# Out:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL  PAGE NO    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...        1  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...        1    Quick Bites
# ...

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df3 = pd.read_csv(r'..\data\output\restaurant_data_with_lat_long_parallel2.csv')
df3.head(5)
# Out:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL  PAGE NO    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...        1  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...        1    Quick Bites
# ...

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df3['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 25080

# %%
df1.update(df3)

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df1['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 32393

# %%
df1.shape
# Out:
# (105623, 15)

# %%
df1.columns
# Out:
# Index(['NAME', 'PRICE', 'CUSINE_CATEGORY', 'CITY', 'REGION', 'URL', 'PAGE NO',
#        'CUSINE TYPE', 'TIMING', 'RATING_TYPE', 'RATING', 'VOTES', 'Latitude',
#        'Longitude', 'ID'],
#       dtype='object')

# %%
# Save the updated DataFrame to a new CSV file
df1.to_csv(r"..\data\output\restaurant_data_with_lat_long_32000.csv", index=False)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df4 = pd.read_csv(r'..\data\output\restaurant_data_with_lat_long_parallel_32000_updated.csv')
df4.head(5)
# Out:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL  PAGE NO    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...        1  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...        1    Quick Bites
# ...

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df4['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 42555

# %%
df1.update(df4)

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df1['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 42555

# %%
# Save the updated DataFrame to a new CSV file
df1.to_csv(r"..\data\output\restaurant_data_with_lat_long_42000.csv", index=False)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df5 = pd.read_csv(r'..\data\output\restaurant_data_with_lat_long_parallel_42000_updated.csv')
df5.head(5)
# Out:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL  PAGE NO    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...        1  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...        1    Quick Bites
# ...

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df5['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 45413

# %%
# Save the updated DataFrame to a new CSV file
df5.to_csv(r"..\data\output\restaurant_data_with_lat_long_45000.csv", index=False)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df6 = pd.read_csv(r'..\data\output\restaurant_data_with_lat_long_parallel_45000_updated.csv')
df6.head(5)
# Out:
#                              NAME  PRICE  \
# 0     The Salt Cafe Kitchen & Bar   1000
# 1                   Bhagat Halwai    300
# 2                     Bikanervala    700
# 3  Mama Chicken Mama Franky House    600
# 4             Honeydew Restaurant    500
#
#                                      CUSINE_CATEGORY  CITY       REGION  \
# 0                   North Indian,Continental,Italian  Agra      Tajganj
# 1             Desserts,Bakery,Fast Food,South Indian  Agra  Civil Lines
# 2  North Indian,South Indian,Mithai,Street Food,D...  Agra     Khandari
# 3  North Indian,Mughlai,Rolls,Chinese,Fast Food,S...  Agra   Agra Cantt
# 4        North Indian,Fast Food,Chinese,South Indian  Agra   Dayal Bagh
#
#                                                  URL  PAGE NO    CUSINE TYPE  \
# 0  https://www.zomato.com/agra/the-salt-cafe-kitc...        1  Casual Dining
# 1  https://www.zomato.com/agra/bhagat-halwai-civi...        1    Quick Bites
# ...

# %%
# Count the non-null values in the 'latitude' column
latitude_values_count = df6['Latitude'].count()

print("Total number of values in the 'latitude' column:", latitude_values_count)
# Out:
# Total number of values in the 'latitude' column: 46664

# %%
# Save the updated DataFrame to a new CSV file
df6.to_csv(r"..\data\output\restaurant_data_with_lat_long_46000.csv", index=False)

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105623 entries, 0 to 105622
# Data columns (total 15 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   NAME             105623 non-null  object
#  1   PRICE            105623 non-null  int64
#  2   CUSINE_CATEGORY  105558 non-null  object
#  3   CITY             105623 non-null  object
#  4   REGION           105623 non-null  object
#  5   URL              105623 non-null  object
#  6   PAGE NO          105623 non-null  int64
#  7   CUSINE TYPE      105623 non-null  object
#  8   TIMING           104982 non-null  object
#  9   RATING_TYPE      95085 non-null   object
#  10  RATING           76418 non-null   float64
#  11  VOTES            105623 non-null  object
#  12  Latitude         46664 non-null   float64
#  13  Longitude        46664 non-null   float64
#  14  ID               105623 non-null  int64
# dtypes: float64(3), int64(3), object(9)
# memory usage: 12.1+ MB
